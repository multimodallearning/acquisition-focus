# %%
run_path_list = list(reversed([
    "rap1ide/slice_inflate/rnts9t9t",
    "rap1ide/slice_inflate/yfgc8stl",
    "rap1ide/slice_inflate/vba7y6vp",
    "rap1ide/slice_inflate/8vbmnmre",
    "rap1ide/slice_inflate/4te8z4rk",
    "rap1ide/slice_inflate/ay7bgyd5",
    "rap1ide/slice_inflate/sfh7xw2p",
    "rap1ide/slice_inflate/zdpeonni",
    "rap1ide/slice_inflate/j16qb5rm",
    "rap1ide/slice_inflate/4kdmc0ch",
    "rap1ide/slice_inflate/mag0njn8",
    "rap1ide/slice_inflate/6d19um8q",
    "rap1ide/slice_inflate/g5hai89a",
    "rap1ide/slice_inflate/31zvi2a0",
    "rap1ide/slice_inflate/f0mu5sbk",
    "rap1ide/slice_inflate/krljgne0",
    "rap1ide/slice_inflate/n41shvul",
    "rap1ide/slice_inflate/wzmr06qe",
    "rap1ide/slice_inflate/0spvd8jj",
    "rap1ide/slice_inflate/jl7prqo8",
    "rap1ide/slice_inflate/n2rf1ae4",
    "rap1ide/slice_inflate/5im33z1m",
    "rap1ide/slice_inflate/j7h289df",
    "rap1ide/slice_inflate/g85qf8ss",
    "rap1ide/slice_inflate/q3963sr5",
    "rap1ide/slice_inflate/tww9c2fm",
    "rap1ide/slice_inflate/y9m2v1b3",
    "rap1ide/slice_inflate/0snhugvl",
    "rap1ide/slice_inflate/a2go54je",
    "rap1ide/slice_inflate/81zajv9e",
]))

# %%
run_name_list = list(reversed([
    '20240125__12_00_59_resultant-rack_stage-3_fold-0',
    '20240125__12_00_59_resultant-rack_stage-2_fold-0',
    '20240125__12_00_59_resultant-rack_stage-1_fold-0',
    '20240125__11_31_39_chill-keyframe_stage-1_fold-2',
    '20240125__11_31_39_vibrant-frequency_stage-1_fold-1',
    '20240125__11_31_39_warm-lepton_stage-1_fold-0',
    '20240125__11_03_37_savory-hangar_stage-1_fold-2',
    '20240125__11_03_37_ascent-incubator_stage-1_fold-1',
    '20240125__11_03_37_crunchy-pouf_stage-1_fold-0',
    '20240125__10_35_37_uniform-cycle_stage-1_fold-2',
    '20240125__10_35_37_mean-goal_stage-1_fold-1',
    '20240125__10_35_37_modern-riser_stage-1_fold-0',
    '20240125__10_07_01_nullary-supervisor_stage-1_fold-2',
    '20240125__10_07_01_tangy-bow_stage-1_fold-1',
    '20240125__10_07_01_cold-yeast_stage-1_fold-0',
    '20240125__09_38_16_clever-relish_stage-1_fold-2',
    '20240125__09_38_16_brute-ion_stage-1_fold-1',
    '20240125__09_38_16_rectilinear-level_stage-1_fold-0',
    '20240125__09_10_32_free-inflection_stage-1_fold-2',
    '20240125__09_10_32_wide-crocodile_stage-1_fold-1',
    '20240125__09_10_32_creamy-web_stage-1_fold-0',
    '20240125__08_41_32_celeste-dataframe_stage-1_fold-2',
    '20240125__08_41_32_deafening-filler_stage-1_fold-1',
    '20240125__08_41_32_brownian-chronology_stage-1_fold-0',
    '20240125__08_14_19_furious-asset_stage-1_fold-2',
    '20240125__08_14_19_deterministic-convergence_stage-1_fold-1',
    '20240125__08_14_19_free-editor_stage-1_fold-0',
    '20240125__07_46_26_violent-relativity_stage-1_fold-2',
    '20240125__07_46_26_free-graph_stage-1_fold-1',
    '20240125__07_46_26_trusting-rosin_stage-1_fold-0',
]))

# %%
import wandb
import pandas as pd

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 1000)


# get n chunks of a list
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

for c_id, (nc, pc) in enumerate(zip(chunks(run_name_list, 3), chunks(run_path_list, 3))):
    print(f"## {c_id}")
    for n, p in zip(nc, pc):
        print(n, "\t", p)
    print()

def get_agg_dict(filtered_frame):
    agg_dict = {
        n: 'first' if t != float else 'mean' for n,t in zip(filtered_frame.columns,filtered_frame.dtypes)
    }
    return agg_dict
# Out:
# ## 0
# 20240125__07_46_26_trusting-rosin_stage-1_fold-0 	 rap1ide/slice_inflate/81zajv9e
# 20240125__07_46_26_free-graph_stage-1_fold-1 	 rap1ide/slice_inflate/a2go54je
# 20240125__07_46_26_violent-relativity_stage-1_fold-2 	 rap1ide/slice_inflate/0snhugvl
#
# ## 1
# 20240125__08_14_19_free-editor_stage-1_fold-0 	 rap1ide/slice_inflate/y9m2v1b3
# 20240125__08_14_19_deterministic-convergence_stage-1_fold-1 	 rap1ide/slice_inflate/tww9c2fm
# 20240125__08_14_19_furious-asset_stage-1_fold-2 	 rap1ide/slice_inflate/q3963sr5
#
# ## 2
# 20240125__08_41_32_brownian-chronology_stage-1_fold-0 	 rap1ide/slice_inflate/g85qf8ss
# 20240125__08_41_32_deafening-filler_stage-1_fold-1 	 rap1ide/slice_inflate/j7h289df
# 20240125__08_41_32_celeste-dataframe_stage-1_fold-2 	 rap1ide/slice_inflate/5im33z1m
#
# ## 3
# 20240125__09_10_32_creamy-web_stage-1_fold-0 	 rap1ide/slice_inflate/n2rf1ae4
# 20240125__09_10_32_wide-crocodile_stage-1_fold-1 	 rap1ide/slice_inflate/jl7prqo8
# 20240125__09_10_32_free-inflection_stage-1_fold-2 	 rap1ide/slice_inflate/0spvd8jj
#
# ## 4
# 20240125__09_38_16_rectilinear-level_stage-1_fold-0 	 rap1ide/slice_inflate/wzmr06qe
# 20240125__09_38_16_brute-ion_stage-1_fold-1 	 rap1ide/slice_inflate/n41shvul
# 20240125__09_38_16_clever-relish_stage-1_fold-2 	 rap1ide/slice_inflate/krljgne0
#
# ## 5
# 20240125__10_07_01_cold-yeast_stage-1_fold-0 	 rap1ide/slice_inflate/f0mu5sbk
# 20240125__10_07_01_tangy-bow_stage-1_fold-1 	 rap1ide/slice_inflate/31zvi2a0
# 20240125__10_07_01_nullary-supervisor_stage-1_fold-2 	 rap1ide/slice_inflate/g5hai89a
#
# ## 6
# 20240125__10_35_37_modern-riser_stage-1_fold-0 	 rap1ide/slice_inflate/6d19um8q
# 20240125__10_35_37_mean-goal_stage-1_fold-1 	 rap1ide/slice_inflate/mag0njn8
# 20240125__10_35_37_uniform-cycle_stage-1_fold-2 	 rap1ide/slice_inflate/4kdmc0ch
#
# ## 7
# 20240125__11_03_37_crunchy-pouf_stage-1_fold-0 	 rap1ide/slice_inflate/j16qb5rm
# 20240125__11_03_37_ascent-incubator_stage-1_fold-1 	 rap1ide/slice_inflate/zdpeonni
# 20240125__11_03_37_savory-hangar_stage-1_fold-2 	 rap1ide/slice_inflate/sfh7xw2p
#
# ## 8
# 20240125__11_31_39_warm-lepton_stage-1_fold-0 	 rap1ide/slice_inflate/ay7bgyd5
# 20240125__11_31_39_vibrant-frequency_stage-1_fold-1 	 rap1ide/slice_inflate/4te8z4rk
# 20240125__11_31_39_chill-keyframe_stage-1_fold-2 	 rap1ide/slice_inflate/8vbmnmre
#
# ## 9
# 20240125__12_00_59_resultant-rack_stage-1_fold-0 	 rap1ide/slice_inflate/vba7y6vp
# 20240125__12_00_59_resultant-rack_stage-2_fold-0 	 rap1ide/slice_inflate/yfgc8stl
# 20240125__12_00_59_resultant-rack_stage-3_fold-0 	 rap1ide/slice_inflate/rnts9t9t

# %% [markdown]
# # MMWHS run dict

# %%
settings = {
   "0:1": dict(description="Clinical standard",
      first_view="p2CH",
      second_view="p4CH",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "1:2": dict(description="Clinical standard",
      first_view="2CH",
      second_view="4CH",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "2:3": dict(description="Clinical standard",
      first_view="2CH",
      second_view="SA",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "3:9": dict(description="Mean out of 6 Random",
      first_view="RND",
      second_view="RND",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "9:10": dict(description="Optimized",
      first_view="AX",
      second_view="COR",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),

   "10:11": dict(description="Clinical standard",
      first_view="best clinical",
      second_view="best clinical",
      prescan_res ="$(6mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "11:12": dict(description="Optimized",
      first_view="best optimized",
      second_view="best optimized",
      prescan_res ="$(6mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),

   "12:13": dict(description="Clinical standard",
      first_view="best clinical",
      second_view="best clinical",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(1.5mm)^2$",
      slice_type="SEG",
   ),
   "13:14": dict(description="Optimized",
      first_view="best optimized",
      second_view="best optimized",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(1.5mm)^2$",
      slice_type="SEG",
   ),

   "14:15": dict(description="Clinical standard",
      first_view="best clinical",
      second_view="best clinical",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(6mm)^3$",
      slice_type="SEG",
   ),
   "15:16": dict(description="Optimized",
      first_view="best optimized",
      second_view="best optimized",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(6mm)^3$",
      slice_type="SEG",
   ),

}

mmwhs_run_dict = {
   ######## 00 ########
   "20240125__07_46_26_trusting-rosin_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/81zajv9e",
      id=0,
      fold=0,
   ),
   "20240125__07_46_26_free-graph_stage-1_fold-1": dict(
      access_key="rap1ide/slice_inflate/a2go54je",
      id=0,
      fold=1,
   ),
   "20240125__07_46_26_violent-relativity_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/0snhugvl",
      id=0,
      fold=2,
   ),

   ######## 01 ########
   "20240125__08_14_19_free-editor_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/y9m2v1b3",
      id=1,
      fold=0,
   ),
   "20240125__08_14_19_deterministic-convergence_stage-1": dict(
      access_key="rap1ide/slice_inflate/tww9c2fm",
      id=1,
      fold=1,
   ),
   "20240125__08_14_19_furious-asset_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/q3963sr5",
      id=1,
      fold=2,
   ),

   ######## 02 ########
   "20240125__08_41_32_brownian-chronology_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/g85qf8ss",
      id=2,
      fold=0,
   ),
   "20240125__08_41_32_deafening-filler_stage-1_fold-1": dict(
      access_key="rap1ide/slice_inflate/j7h289df",
      id=2,
      fold=1,
   ),
   "20240125__08_41_32_celeste-dataframe_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/5im33z1m",
      id=2,
      fold=2,
   ),

   ######## 03 ########
   "20240125__09_10_32_creamy-web_stage-1_fold-0 ": dict(
      access_key="rap1ide/slice_inflate/n2rf1ae4",
      id=3,
      fold=0,
   ),
   "20240125__09_10_32_wide-crocodile_stage-1_fold-1": dict(
      access_key="rap1ide/slice_inflate/jl7prqo8",
      id=3,
      fold=1,
   ),
   "20240125__09_10_32_free-inflection_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/0spvd8jj",
      id=3,
      fold=2,
   ),

   ######## 04 ########
   "20240125__09_38_16_rectilinear-level_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/wzmr06qe",
      id=4,
      fold=0,
   ),
   "20240125__09_38_16_brute-ion_stage-1_fold-1": dict(
      access_key="rap1ide/slice_inflate/n41shvul",
      id=4,
      fold=1,
   ),
   "20240125__09_38_16_clever-relish_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/krljgne0",
      id=4,
      fold=2,
   ),

   ######## 05 ########
   "20240125__10_07_01_cold-yeast_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/f0mu5sbk",
      id=5,
      fold=0,
   ),
   "20240125__10_07_01_tangy-bow_stage-1_fold-1": dict(
      access_key="rap1ide/slice_inflate/31zvi2a0",
      id=5,
      fold=1,
   ),
   "20240125__10_07_01_nullary-supervisor_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/g5hai89a",
      id=5,
      fold=2,
   ),

   ######## 06 ########
   "20240125__10_35_37_modern-riser_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/6d19um8q",
      id=6,
      fold=0,
   ),
   "20240125__10_35_37_mean-goal_stage-1_fold-1": dict(
      access_key="rap1ide/slice_inflate/mag0njn8",
      id=6,
      fold=1,
   ),
   "20240125__10_35_37_uniform-cycle_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/4kdmc0ch",
      id=6,
      fold=2,
   ),

   ######## 07 ########
   "20240125__11_03_37_crunchy-pouf_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/j16qb5rm",
      id=7,
      fold=0,
   ),
   "20240125__11_03_37_savory-hangar_stage-1_fold-2 ": dict(
      access_key="rap1ide/slice_inflate/zdpeonni",
      id=7,
      fold=1,
   ),
   "20240125__11_03_37_savory-hangar_stage-1_fold-2": dict(
      access_key="rap1ide/slice_inflate/sfh7xw2p",
      id=7,
      fold=2,
   ),
   ######## 08 ########
   "20240125__11_31_39_warm-lepton_stage-1_fold-0": dict(
      access_key="rap1ide/slice_inflate/ay7bgyd5",
      id=8,
      fold=0,
   ),
   "20240125__11_31_39_vibrant-frequency_stage-1_fold-1": dict(
      access_key="rap1ide/slice_inflate/4te8z4rk",
      id=8,
      fold=1,
   ),
   "20240125__11_31_39_chill-keyframe_stage-1_fold-2 ": dict(
      access_key="rap1ide/slice_inflate/8vbmnmre",
      id=8,
      fold=2,
   ),

   ######## 09 ########
   "dummy27": dict( # TODO change this to the correct run
      access_key="rap1ide/slice_inflate/yfgc8stl",
      id=9,
      fold=0,
   ),
   "dummy28": dict(
      access_key="rap1ide/slice_inflate/yfgc8stl",
      id=9,
      fold=1,
   ),
   "dummy29": dict(
      access_key="rap1ide/slice_inflate/yfgc8stl",
      id=9,
      fold=2,
   ),

   ######## 10 ########
   "dummy30": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=10,
      fold=0,
   ),
   "dummy31": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=10,
      fold=1,
   ),
   "dummy32": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=10,
      fold=2,
   ),

   ######## 11 ########
   "dummy33": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=11,
      fold=0,
   ),
   "dummy34": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=11,
      fold=1,
   ),
   "dummy35": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=11,
      fold=2,
   ),
   ######## 12 ########
   "dummy36": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=12,
      fold=0,
   ),
   "dummy37": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=12,
      fold=1,
   ),
   "dummy38": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=12,
      fold=2,
   ),

   ######## 13 ########
   "dummy39": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=13,
      fold=0,
   ),
   "dummy40": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=13,
      fold=1,
   ),
   "dummy41": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=13,
      fold=2,
   ),

   ######## 14 ########
   "dummy42": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=14,
      fold=0,
   ),
   "dummy43": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=14,
      fold=1,
   ),
   "dummy44": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=14,
      fold=2,
   ),

   ######## 15 ########
   "dummy45": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=15,
      fold=0,
   ),
   "dummy46": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=15,
      fold=1,
   ),
   "dummy47": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=15,
      fold=2,
   ),
}

df = pd.DataFrame()

api = wandb.Api()

for run_idx, (wandb_run_name, rr) in enumerate(mmwhs_run_dict.items()):
   run_key = rr['access_key']
   run_numeric_id = rr['id']
   try:
      wrun = api.run(run_key)
   except:
      print(f"Failed to fetch run {run_key}")
      continue

   run_frame = pd.DataFrame(wrun.history())
   run_frame = run_frame.iloc[-1:]
   run_frame.index = [run_idx]


   if 3 <= run_numeric_id < 9:
      run_settings = settings['3:9']
   else:
      run_settings = settings[f"{run_numeric_id}:{run_numeric_id+1}"]

   run_frame.insert(0, '_id', [rr['id']])
   run_frame.insert(1, 'description', [run_settings['description']])
   run_frame.insert(2, 'first_view', run_settings['first_view'])
   run_frame.insert(3, 'second_view', run_settings['second_view'])
   run_frame.insert(4, 'prescan_res', run_settings['prescan_res'])
   run_frame.insert(5, 'prescan_type', run_settings['prescan_type'])
   run_frame.insert(6, 'slice_res', run_settings['slice_res'])
   run_frame.insert(7, 'slice_type', run_settings['slice_type'])
   run_frame.insert(8, 'fold', rr['fold'])

   df = pd.concat([df,run_frame])

df
# Out:
#     _id        description      first_view     second_view  prescan_res prescan_type    slice_res slice_type  fold  scores/train_mean_oa_exclude_bg_hd  ...  orientations/test_hla_theta_ap3_std  orientations/val_hla_theta_t_offsets0_std  orientations/train_hla_theta_zp0_std  orientations/train_sa_theta_ap2_mean  orientations/val_hla_theta_ap0_std  orientations/train_sa_theta_ap1_mean  orientations/val_sa_theta_ap0_std  orientations/train_hla_theta_t_offsets2_mean  orientations/val_sa_theta_ap3_std  orientations/val_sa_theta_t_offsets2_mean
# 0     0  Clinical standard            p2CH            p4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     0                           52.665875  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 1     0  Clinical standard            p2CH            p4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     1                           49.543429  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 2     0  Clinical standard            p2CH            p4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     2                           44.097100  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 3     1  Clinical standard             2CH             4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     0                           49.328646  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 4     1  Clinical standard             2CH             4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     1                           48.897131  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# ..  ...                ...             ...             ...          ...          ...          ...        ...   ...                                 ...  ...                                  ...                                        ...                                   ...                                   ...                                 ...                                   ...                                ...                                           ...                                ...                                        ...
# 43   14  Clinical standard   best clinical   best clinical    $(6mm)^3$          SEG    $(6mm)^3$        SEG     1                           15.465120  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 44   14  Clinical standard   best clinical   best clinical    $(6mm)^3$          SEG    $(6mm)^3$        SEG     2                           15.465120  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 45   15          Optimized  best optimized  best optimized    $(6mm)^3$          SEG    $(6mm)^3$        SEG     0                           15.465120  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 46   15          Optimized  best optimized  best optimized    $(6mm)^3$          SEG    $(6mm)^3$        SEG     1                           15.465120  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
# 47   15          Optimized  best optimized  best optimized    $(6mm)^3$          SEG    $(6mm)^3$        SEG     2                           15.465120  ...                                  NaN                                        NaN                                   NaN                                   NaN                                 NaN                                   NaN                                NaN                                           NaN                                NaN                                        NaN
#
# [48 rows x 354 columns]

# %%
wanted_keys = {
    '_id': '_id',
    'prescan_res': 'Precsan props.',
    # 'description': 'Description',
    'prescan_type': 'Prescan props.',
    'slice_res': 'Slice resolution',
    'slice_type': 'Slice props.',
    'first_view': 'Slice view(s)',
    'second_view': 'Second view',
    'fold': 'fold',
    'scores/val_mean_dice_MYO': 'MYO',
    'scores/val_mean_dice_LV': 'LV',
    'scores/val_mean_dice_RV': 'RV',
    'scores/val_mean_dice_LA': 'LA',
    'scores/val_mean_dice_RA': 'RA',

    'scores/val_mean_oa_exclude_bg_dice': '\multicolumn{1}{c}{ALL$\pm\sigma$ }',
    'scores/val_std_oa_exclude_bg_dice': 'N/A',

    'scores/val_mean_hd95_MYO': 'MYO',
    'scores/val_mean_hd95_LV': 'LV',
    'scores/val_mean_hd95_RV': 'RV',
    'scores/val_mean_hd95_LA': 'LA',
    'scores/val_mean_hd95_RA': 'RA',
    'scores/val_mean_oa_exclude_bg_hd95': '\multicolumn{1}{c}{ALL$\pm\sigma$  }',
    'scores/val_std_oa_exclude_bg_hd95': 'N/A',

    # 'scores/val_mean_oa_exclude_bg_iou': 'IOU',
    # 'scores/val_std_oa_exclude_bg_iou': '',

    'scores/val_mean_delta_vol_rel_LV': '\multicolumn{1}{c}{ALL$\pm\sigma$   }',
    'scores/val_std_delta_vol_rel_LV': '',
}

# %%
filtered_frame = df.copy()
filtered_frame = filtered_frame.groupby('_id').agg(get_agg_dict(filtered_frame))

# %%
filtered_frame = filtered_frame[wanted_keys.keys()]

percent_keys = [k for k in wanted_keys if "dice" in k or "vol_rel" in k]
mean_keys = [k for k in wanted_keys if "mean" in k]
min_metrics_keys = [k for k in wanted_keys if ("delta" in k or "hd" in k) and not 'std' in k]
max_metrics_keys = [k for k in wanted_keys if ("dice" in k or "iou" in k) and not 'std' in k]

filtered_frame.loc[:,percent_keys] *= 100.
filtered_frame
# Out:
#      _id  prescan_res prescan_type    slice_res slice_type      first_view     second_view  fold  scores/val_mean_dice_MYO  scores/val_mean_dice_LV  ...  scores/val_std_oa_exclude_bg_dice  scores/val_mean_hd95_MYO  scores/val_mean_hd95_LV  scores/val_mean_hd95_RV  scores/val_mean_hd95_LA  scores/val_mean_hd95_RA  scores/val_mean_oa_exclude_bg_hd95  scores/val_std_oa_exclude_bg_hd95  scores/val_mean_delta_vol_rel_LV  scores/val_std_delta_vol_rel_LV
# _id                                                                                                                                                  ...
# 0      0  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT            p2CH            p4CH     0                 80.721520                91.136554  ...                           8.999896                  8.558464                 8.390313                18.271347                19.240794                25.015523                           15.895288                          11.132938                          8.466886                         7.161077
# 1      1  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             2CH             4CH     0                 78.526341                89.716278  ...                           8.041966                  7.904733                 8.917417                20.559228                14.355378                21.834519                           14.714255                           9.185086                         10.058666                         9.330193
# 2      2  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             2CH              SA     0                 77.186849                88.339128  ...                          10.168968                  8.416033                11.540215                21.278951                22.606257                31.520180                           19.072327                          10.806368                         10.280678                         6.043985
# 3      3  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             RND             RND     0                 69.241411                83.381905  ...                          11.233071                 12.757612                14.260062                25.688940                25.611940                21.101054                           19.883922                          14.943460                         14.673267                        15.284158
# 4      4  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             RND             RND     0                 66.228298                82.439418  ...                          10.925131                 14.521917                16.248530                25.117303                19.911981                24.998236                           20.159593                          12.313059                         18.772253                        17.775156
# 5      5  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             RND             RND     0                 67.417168                80.113683  ...                          12.178163                 14.180841                16.783485                22.502434                25.200399                23.544067                           20.442245                          13.203804                         17.357091                        11.100706
# 6      6  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             RND             RND     0                 68.595567                83.803544  ...                          11.169135                 13.137338                13.885208                21.117427                23.314431                25.890221                           19.468925                          13.059518                         17.072661                        18.944236
# 7      7  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             RND             RND     0                 64.589739                81.273842  ...                          11.675559                 14.585245                16.598739                27.468253                20.992545                24.604224                           20.849801                          12.608204                         13.321304                         9.392687
# 8      8  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             RND             RND     0                 66.690223                82.383162  ...                          10.939700                 12.648777                14.297434                20.090185                17.381116                22.344160                           17.352334                           8.938247                         17.756084                        13.553680
# 9      9  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT              AX             COR     0                 65.171794                81.126031  ...                          10.320889                 14.611036                15.863585                28.367123                24.647895                32.914408                           23.280809                           9.613793                         20.287302                        20.515536
# 10    10    $(6mm)^3$           GT  $(1.5mm)^2$         GT   best clinical   best clinical     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 11    11    $(6mm)^3$           GT  $(1.5mm)^2$         GT  best optimized  best optimized     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 12    12    $(6mm)^3$          SEG  $(1.5mm)^2$        SEG   best clinical   best clinical     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 13    13    $(6mm)^3$          SEG  $(1.5mm)^2$        SEG  best optimized  best optimized     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 14    14    $(6mm)^3$          SEG    $(6mm)^3$        SEG   best clinical   best clinical     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 15    15    $(6mm)^3$          SEG    $(6mm)^3$        SEG  best optimized  best optimized     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
#
# [16 rows x 24 columns]

# %%
random_runs = list(range(0,3)) + 6 * ['is_random'] + list(range(9,16))
filtered_frame.insert(1, 'is_random', random_runs)
filtered_frame = filtered_frame.groupby('is_random', as_index=False).agg(get_agg_dict(filtered_frame))

reindex_idx = list(range(0,3)) + [-1] + list(range(3,10))
filtered_frame = filtered_frame.iloc[reindex_idx,:]
filtered_frame.drop('is_random', axis=1, inplace=True)
filtered_frame
# Out:
#     _id  prescan_res prescan_type    slice_res slice_type      first_view     second_view  fold  scores/val_mean_dice_MYO  scores/val_mean_dice_LV  ...  scores/val_std_oa_exclude_bg_dice  scores/val_mean_hd95_MYO  scores/val_mean_hd95_LV  scores/val_mean_hd95_RV  scores/val_mean_hd95_LA  scores/val_mean_hd95_RA  scores/val_mean_oa_exclude_bg_hd95  scores/val_std_oa_exclude_bg_hd95  scores/val_mean_delta_vol_rel_LV  scores/val_std_delta_vol_rel_LV
# 0     0  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT            p2CH            p4CH     0                 80.721520                91.136554  ...                           8.999896                  8.558464                 8.390313                18.271347                19.240794                25.015523                           15.895288                          11.132938                          8.466886                         7.161077
# 1     1  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             2CH             4CH     0                 78.526341                89.716278  ...                           8.041966                  7.904733                 8.917417                20.559228                14.355378                21.834519                           14.714255                           9.185086                         10.058666                         9.330193
# 2     2  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             2CH              SA     0                 77.186849                88.339128  ...                          10.168968                  8.416033                11.540215                21.278951                22.606257                31.520180                           19.072327                          10.806368                         10.280678                         6.043985
# 10    3  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT             RND             RND     0                 67.127068                82.232592  ...                          11.353460                 13.638622                15.345576                23.664090                22.068735                23.746994                           19.692804                          12.511049                         16.492110                        14.341770
# 3     9  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT              AX             COR     0                 65.171794                81.126031  ...                          10.320889                 14.611036                15.863585                28.367123                24.647895                32.914408                           23.280809                           9.613793                         20.287302                        20.515536
# 4    10    $(6mm)^3$           GT  $(1.5mm)^2$         GT   best clinical   best clinical     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 5    11    $(6mm)^3$           GT  $(1.5mm)^2$         GT  best optimized  best optimized     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 6    12    $(6mm)^3$          SEG  $(1.5mm)^2$        SEG   best clinical   best clinical     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 7    13    $(6mm)^3$          SEG  $(1.5mm)^2$        SEG  best optimized  best optimized     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 8    14    $(6mm)^3$          SEG    $(6mm)^3$        SEG   best clinical   best clinical     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
# 9    15    $(6mm)^3$          SEG    $(6mm)^3$        SEG  best optimized  best optimized     0                 82.890800                91.751782  ...                           9.988355                  7.327352                 5.882277                16.970151                15.214810                23.698479                           13.818614                           7.953023                          3.796195                         3.018810
#
# [11 rows x 24 columns]

# %%
exp_frame =filtered_frame.copy()

# %%
group_ranges = [
    [0,5],
    [5,7],
    [7,9],
    [9,11],
]

bold_idxs = []
for sub_range in group_ranges:
    sub_frame = filtered_frame.iloc[sub_range[0]:sub_range[1]]
    optimal_vals_maximize = sub_frame[max_metrics_keys].idxmax()
    optimal_vals_minimize = sub_frame[min_metrics_keys].idxmin()

    bold_idxs.append(optimal_vals_maximize)
    bold_idxs.append(optimal_vals_minimize)

# bold_idxs

# %%
filtered_frame = filtered_frame.round(decimals=1)

# optimal_vals_maximize = filtered_frame[max_metrics_keys].idxmax()
# optimal_vals_minimize = filtered_frame[min_metrics_keys].idxmin()

string_frame = filtered_frame.copy().astype(str)

# Fuse mean and std columns
for m in mean_keys:
    mean_col = string_frame[m].astype(str)
    std_col_key = m.replace("mean","std")
    if std_col_key in string_frame.columns:
        std_col = string_frame[std_col_key].astype(str)
        string_frame[m] = mean_col + r" \pm " + std_col
        string_frame.drop(std_col_key, axis=1, inplace=True)


# Add bold to optimal values
for bold_group in bold_idxs:
    for col_name, idx in zip(bold_group.index, bold_group.values):
        row_idx = string_frame.index.get_loc(idx)
        col_idx = string_frame.columns.get_loc(col_name)
        string_frame.iloc[row_idx,col_idx] = r"\B " + string_frame.iloc[row_idx,col_idx]

# for col_name, idx in zip(optimal_vals_minimize.index, optimal_vals_minimize.values):
#     row_idx = string_frame.index.get_loc(idx)
#     col_idx = string_frame.columns.get_loc(col_name)
#     string_frame.iloc[row_idx,col_idx] = r"\B " + string_frame.iloc[row_idx,col_idx]

# for col_name, idx in zip(optimal_vals_maximize.index, optimal_vals_maximize.values):
#     row_idx = string_frame.index.get_loc(idx)
#     col_idx = string_frame.columns.get_loc(col_name)
#     string_frame.iloc[row_idx,col_idx] = r"\B " + string_frame.iloc[row_idx,col_idx]

def join_cols(frame, first_col_key, second_col_key, join_str="+", drop_second=True):
    first_col = frame[first_col_key].astype(str)
    second_col = frame[second_col_key].astype(str)
    frame[first_col_key] = first_col + join_str + second_col
    if drop_second:
        frame.drop(second_col_key, axis=1, inplace=True)
    else:
        frame.drop(first_col_key, axis=1, inplace=True)
    return frame

# Join first and second view
string_frame = join_cols(string_frame, 'first_view', 'second_view', join_str=r"+")
string_frame = join_cols(string_frame, 'prescan_type', 'prescan_res', join_str=r" ", drop_second=True)
string_frame = join_cols(string_frame, 'slice_type', 'slice_res', join_str=r" ", drop_second=True)


# Replace column names
string_frame.columns = [wanted_keys[c] for c in string_frame.columns]

string_frame.drop('_id', axis=1, inplace=True)
string_frame.drop('fold', axis=1, inplace=True)

string_frame.insert(3, ' ', len(string_frame)*["\hspace{1pt}"])
string_frame.insert(10, '  ', len(string_frame)*["\hspace{1pt}"])
string_frame.insert(17, '   ', len(string_frame)*["\hspace{1pt}"])

for group_idxs in group_ranges:
    txt = string_frame.iloc[group_idxs[1]-1,0]
    string_frame.iloc[group_idxs[1]-1,0] = r"\rule{0pt}{4ex} "+txt

string_frame
# Out:
#                     Prescan props.     Slice props.                  Slice view(s)                    MYO       LV       RV       LA       RA \multicolumn{1}{c}{ALL$\pm\sigma$ }                   MYO      LV       RV       LA       RA \multicolumn{1}{c}{ALL$\pm\sigma$  }               \multicolumn{1}{c}{ALL$\pm\sigma$   }
# 0                   GT $(1.5mm)^3$   GT $(1.5mm)^2$                      p2CH+p4CH  \hspace{1pt}  \B 80.7  \B 91.1     77.4     76.1     74.4                        80.0 \pm 9.0  \hspace{1pt}     8.6  \B 8.4  \B 18.3     19.2     25.0                        15.9 \pm 11.1  \hspace{1pt}                        \B 8.5 \pm 7.2
# 1                   GT $(1.5mm)^3$   GT $(1.5mm)^2$                        2CH+4CH  \hspace{1pt}     78.5     89.7  \B 77.6  \B 80.8  \B 74.7                     \B 80.3 \pm 8.0  \hspace{1pt}  \B 7.9     8.9     20.6  \B 14.4  \B 21.8                      \B 14.7 \pm 9.2  \hspace{1pt}                          10.1 \pm 9.3
# 2                   GT $(1.5mm)^3$   GT $(1.5mm)^2$                         2CH+SA  \hspace{1pt}     77.2     88.3     74.8     72.0     63.1                       75.1 \pm 10.2  \hspace{1pt}     8.4    11.5     21.3     22.6     31.5                        19.1 \pm 10.8  \hspace{1pt}                          10.3 \pm 6.0
# 10                  GT $(1.5mm)^3$   GT $(1.5mm)^2$                        RND+RND  \hspace{1pt}     67.1     82.2     75.3     71.2     73.0                       73.8 \pm 11.4  \hspace{1pt}    13.6    15.3     23.7     22.1     23.7                        19.7 \pm 12.5  \hspace{1pt}                         16.5 \pm 14.3
# 3   \rule{0pt}{4ex} GT $(1.5mm)^3$   GT $(1.5mm)^2$                         AX+COR  \hspace{1pt}     65.2     81.1     68.4     64.9     65.6                       69.0 \pm 10.3  \hspace{1pt}    14.6    15.9     28.4     24.6     32.9                         23.3 \pm 9.6  \hspace{1pt}                         20.3 \pm 20.5
# 4                     GT $(6mm)^3$   GT $(1.5mm)^2$    best clinical+best clinical  \hspace{1pt}  \B 82.9  \B 91.8  \B 77.8  \B 79.3  \B 66.6                    \B 79.7 \pm 10.0  \hspace{1pt}  \B 7.3  \B 5.9  \B 17.0  \B 15.2  \B 23.7                      \B 13.8 \pm 8.0  \hspace{1pt}                        \B 3.8 \pm 3.0
# 5     \rule{0pt}{4ex} GT $(6mm)^3$   GT $(1.5mm)^2$  best optimized+best optimized  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 6                    SEG $(6mm)^3$  SEG $(1.5mm)^2$    best clinical+best clinical  \hspace{1pt}  \B 82.9  \B 91.8  \B 77.8  \B 79.3  \B 66.6                    \B 79.7 \pm 10.0  \hspace{1pt}  \B 7.3  \B 5.9  \B 17.0  \B 15.2  \B 23.7                      \B 13.8 \pm 8.0  \hspace{1pt}                        \B 3.8 \pm 3.0
# 7    \rule{0pt}{4ex} SEG $(6mm)^3$  SEG $(1.5mm)^2$  best optimized+best optimized  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 8                    SEG $(6mm)^3$    SEG $(6mm)^3$    best clinical+best clinical  \hspace{1pt}  \B 82.9  \B 91.8  \B 77.8  \B 79.3  \B 66.6                    \B 79.7 \pm 10.0  \hspace{1pt}  \B 7.3  \B 5.9  \B 17.0  \B 15.2  \B 23.7                      \B 13.8 \pm 8.0  \hspace{1pt}                        \B 3.8 \pm 3.0
# 9    \rule{0pt}{4ex} SEG $(6mm)^3$    SEG $(6mm)^3$  best optimized+best optimized  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0

# %%
PM_COL_FORMAT = "S[table-figures-decimal=1,separate-uncertainty=true,table-format=3.1(3)]"
COL_FORMAT = \
    ("c" * 9) \
    + PM_COL_FORMAT \
    + ("c" * 6) \
    + PM_COL_FORMAT \
    + "c" \
    + PM_COL_FORMAT
# 19 cols

header = [r'\multicolumn{3}{c}{\textbf{Experiment I}}'] \
    + 2*[None] \
    + [r'\hspace{1pt}'] \
    + [r'\multicolumn{6}{c}{\textbf{Dice in \% $\uparrow$}}'] + 5*[None] \
    + [r'\hspace{1pt}'] \
    + [r'\multicolumn{6}{c}{\textbf{HD95 in mm $\downarrow$}}'] + 5*[None] \
    + [r'\hspace{1pt}'] \
    + [r'\textbf{$\Delta$vol in \%}']

latex_frame = pd.concat([pd.DataFrame(header, index=string_frame.columns).T, string_frame])

latex_frame.to_latex(
    buf="mmwhs_results.txt",
    escape=False,
    column_format=COL_FORMAT,
    index=False,
)

# Load latex file and replace & NaN with &
with open("mmwhs_results.txt", "r") as f:
    lines = f.readlines()

    lines = [l.replace("& NaN", "") for l in lines]

with open("mmwhs_results.txt", "w") as f:
    f.writelines(lines)

# Insert 5th line before third line
with open("mmwhs_results.txt", "r") as f:
    lines = f.readlines()
    lines.insert(2, lines[4])
    del lines[5]
with open("mmwhs_results.txt", "w") as f:
    f.writelines(lines)
