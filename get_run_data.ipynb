# %%
import wandb
import pandas as pd

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 1000)

settings = {
   "0:1": dict(description="Clinical standard",
      first_view="p2CH",
      second_view="p4CH",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "1:2": dict(description="Clinical standard",
      first_view="2CH",
      second_view="4CH",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "2:3": dict(description="Clinical standard",
      first_view="2CH",
      second_view="SA",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "3:9": dict(description="Mean out of 6 Random",
      first_view="RND",
      second_view="RND",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "9:10": dict(description="Optimized",
      first_view="AX",
      second_view="COR",
      prescan_res ="$(1.5mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),

   "10:11": dict(description="Clinical standard",
      first_view="best clinical",
      second_view="best clinical",
      prescan_res ="$(6mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),
   "11:12": dict(description="Optimized",
      first_view="best optimized",
      second_view="best optimized",
      prescan_res ="$(6mm)^3$",
      prescan_type ="GT",
      slice_res ="$(1.5mm)^2$",
      slice_type="GT",
   ),

   "12:13": dict(description="Clinical standard",
      first_view="best clinical",
      second_view="best clinical",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(1.5mm)^2$",
      slice_type="SEG",
   ),
   "13:14": dict(description="Optimized",
      first_view="best optimized",
      second_view="best optimized",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(1.5mm)^2$",
      slice_type="SEG",
   ),

   "14:15": dict(description="Clinical standard",
      first_view="best clinical",
      second_view="best clinical",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(6mm)^3$",
      slice_type="SEG",
   ),
   "15:16": dict(description="Optimized",
      first_view="best optimized",
      second_view="best optimized",
      prescan_res ="$(6mm)^3$",
      prescan_type ="SEG",
      slice_res ="$(6mm)^3$",
      slice_type="SEG",
   ),

}

mmwhs_run_dict = {
   ######## 00 ########
   "20240123__13_16_58_adagio-vector_stage-3_fold-0": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=0,
      fold=0,
   ),
   "dummy1": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=0,
      fold=1,
   ),
   "dummy2": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=0,
      fold=2,
   ),

   ######## 01 ########
   "dummy3": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=1,
      fold=0,
   ),
   "dummy4": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=1,
      fold=1,
   ),
   "dummy5": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=1,
      fold=2,
   ),

   ######## 02 ########
   "dummy6": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=2,
      fold=0,
   ),
   "dummy7": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=2,
      fold=1,
   ),
   "dummy8": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=2,
      fold=2,
   ),

   ######## 03 ########
   "dummy9": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=3,
      fold=0,
   ),
   "dummy10": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=3,
      fold=1,
   ),
   "dummy11": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=3,
      fold=2,
   ),

   ######## 04 ########
   "dummy12": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=4,
      fold=0,
   ),
   "dummy13": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=4,
      fold=1,
   ),
   "dummy14": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=4,
      fold=2,
   ),

   ######## 05 ########
   "dummy15": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=5,
      fold=0,
   ),
   "dummy16": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=5,
      fold=1,
   ),
   "dummy17": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=5,
      fold=2,
   ),

   ######## 06 ########
   "dummy18": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=6,
      fold=0,
   ),
   "dummy19": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=6,
      fold=1,
   ),
   "dummy20": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=6,
      fold=2,
   ),

   ######## 07 ########
   "dummy21": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=7,
      fold=0,
   ),
   "dummy22": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=7,
      fold=1,
   ),
   "dummy23": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=7,
      fold=2,
   ),
   ######## 08 ########
   "dumm24": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=8,
      fold=0,
   ),
   "dummy25": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=8,
      fold=1,
   ),
   "dummy26": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=8,
      fold=2,
   ),

   ######## 09 ########
   "dummy27": dict( # TODO delete this..
      access_key="rap1ide/slice_inflate/inu5aqlv",
      id=9,
      fold=0,
   ),
   "dummy28": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=9,
      fold=1,
   ),
   "dummy29": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=9,
      fold=2,
   ),

   ######## 10 ########
   "dummy30": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=10,
      fold=0,
   ),
   "dummy31": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=10,
      fold=1,
   ),
   "dummy32": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=10,
      fold=2,
   ),

   ######## 11 ########
   "dummy33": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=11,
      fold=0,
   ),
   "dummy34": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=11,
      fold=1,
   ),
   "dummy35": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=11,
      fold=2,
   ),
   ######## 12 ########
   "dummy36": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=12,
      fold=0,
   ),
   "dummy37": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=12,
      fold=1,
   ),
   "dummy38": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=12,
      fold=2,
   ),

   ######## 13 ########
   "dummy39": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=13,
      fold=0,
   ),
   "dummy40": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=13,
      fold=1,
   ),
   "dummy41": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=13,
      fold=2,
   ),

   ######## 14 ########
   "dummy42": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=14,
      fold=0,
   ),
   "dummy43": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=14,
      fold=1,
   ),
   "dummy44": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=14,
      fold=2,
   ),

   ######## 15 ########
   "dummy45": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=15,
      fold=0,
   ),
   "dummy46": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=15,
      fold=1,
   ),
   "dummy47": dict(
      access_key="rap1ide/slice_inflate/fkcbrd5p",
      id=15,
      fold=2,
   ),
}

df = pd.DataFrame()

api = wandb.Api()

for run_idx, (wandb_run_name, rr) in enumerate(mmwhs_run_dict.items()):
   run_key = rr['access_key']
   run_numeric_id = rr['id']
   try:
      wrun = api.run(run_key)
   except:
      print(f"Failed to fetch run {run_key}")
      continue

   run_frame = pd.DataFrame(wrun.history())
   run_frame = run_frame.iloc[-1:]
   run_frame.index = [run_idx]


   if 3 <= run_numeric_id < 9:
      run_settings = settings['3:9']
   else:
      run_settings = settings[f"{run_numeric_id}:{run_numeric_id+1}"]

   run_frame.insert(0, '_id', [rr['id']])
   run_frame.insert(1, 'description', [run_settings['description']])
   run_frame.insert(2, 'first_view', run_settings['first_view'])
   run_frame.insert(3, 'second_view', run_settings['second_view'])
   run_frame.insert(4, 'prescan_res', run_settings['prescan_res'])
   run_frame.insert(5, 'prescan_type', run_settings['prescan_type'])
   run_frame.insert(6, 'slice_res', run_settings['slice_res'])
   run_frame.insert(7, 'slice_type', run_settings['slice_type'])
   run_frame.insert(8, 'fold', rr['fold'])

   df = pd.concat([df,run_frame])

df
# Out:
#     _id        description      first_view     second_view  prescan_res prescan_type    slice_res slice_type  fold  scores/test_mean_oa_exclude_bg_hd  ...  orientations/val_sa_theta_ap0_mean  orientations/test_sa_theta_ap4_std  orientations/val_hla_theta_t_offsets1_std  orientations/train_sa_theta_zp0_std  orientations/val_hla_theta_ap3_std  orientations/test_hla_theta_ap1_mean  orientations/test_sa_theta_ap2_mean  orientations/val_sa_theta_t_offsets2_std  orientations/train_hla_theta_ap4_std  orientations/test_hla_theta_ap2_mean
# 0     0  Clinical standard            p2CH            p4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     0                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 1     0  Clinical standard            p2CH            p4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     1                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 2     0  Clinical standard            p2CH            p4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     2                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 3     1  Clinical standard             2CH             4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     0                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 4     1  Clinical standard             2CH             4CH  $(1.5mm)^3$           GT  $(1.5mm)^2$         GT     1                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# ..  ...                ...             ...             ...          ...          ...          ...        ...   ...                                ...  ...                                 ...                                 ...                                        ...                                  ...                                 ...                                   ...                                  ...                                       ...                                   ...                                   ...
# 43   14  Clinical standard   best clinical   best clinical    $(6mm)^3$          SEG    $(6mm)^3$        SEG     1                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 44   14  Clinical standard   best clinical   best clinical    $(6mm)^3$          SEG    $(6mm)^3$        SEG     2                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 45   15          Optimized  best optimized  best optimized    $(6mm)^3$          SEG    $(6mm)^3$        SEG     0                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 46   15          Optimized  best optimized  best optimized    $(6mm)^3$          SEG    $(6mm)^3$        SEG     1                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
# 47   15          Optimized  best optimized  best optimized    $(6mm)^3$          SEG    $(6mm)^3$        SEG     2                          43.877066  ...                                 NaN                                 NaN                                        NaN                                  NaN                                 NaN                                   NaN                                  NaN                                       NaN                                   NaN                                   NaN
#
# [48 rows x 354 columns]

# %%
wanted_keys = {
    '_id': '_id',
    'prescan_res': 'Precsan props.',
    'first_view': 'Slice view(s)',
    'second_view': 'Second view',
    # 'description': 'Description',
    'prescan_type': 'Prescan props.',
    'slice_res': 'Slice resolution',
    'slice_type': 'Slice props.',
    'fold': 'fold',
    'scores/val_mean_dice_MYO': 'MYO',
    'scores/val_mean_dice_LV': 'LV',
    'scores/val_mean_dice_RV': 'RV',
    'scores/val_mean_dice_LA': 'LA',
    'scores/val_mean_dice_RA': 'RA',

    'scores/val_mean_oa_exclude_bg_dice': '\multicolumn{1}{c}{ALL$\pm\sigma$ }',
    'scores/val_std_oa_exclude_bg_dice': 'N/A',

    'scores/val_mean_hd95_MYO': 'MYO',
    'scores/val_mean_hd95_LV': 'LV',
    'scores/val_mean_hd95_RV': 'RV',
    'scores/val_mean_hd95_LA': 'LA',
    'scores/val_mean_hd95_RA': 'RA',
    'scores/val_mean_oa_exclude_bg_hd95': '\multicolumn{1}{c}{ALL$\pm\sigma$  }',
    'scores/val_std_oa_exclude_bg_hd95': 'N/A',

    # 'scores/val_mean_oa_exclude_bg_iou': 'IOU',
    # 'scores/val_std_oa_exclude_bg_iou': '',

    'scores/val_mean_delta_vol_rel_LV': '\multicolumn{1}{c}{ALL$\pm\sigma$   }',
    'scores/val_std_delta_vol_rel_LV': '',
}

# %%
filtered_frame = df.copy()

agg_dict = {
    n: 'first' if t != float else 'mean' for n,t in zip(filtered_frame.columns,filtered_frame.dtypes)
}

filtered_frame = filtered_frame.groupby('_id').agg(agg_dict)

# %%
filtered_frame = filtered_frame[wanted_keys.keys()]

percent_keys = [k for k in wanted_keys if "dice" in k or "vol_rel" in k]
mean_keys = [k for k in wanted_keys if "mean" in k]
min_metrics_keys = [k for k in wanted_keys if ("delta" in k or "hd" in k) and not 'std' in k]
max_metrics_keys = [k for k in wanted_keys if ("dice" in k or "iou" in k) and not 'std' in k]

filtered_frame.loc[:,percent_keys] *= 100.
filtered_frame = filtered_frame.round(decimals=1)
filtered_frame
# Out:
#      _id  prescan_res      first_view     second_view prescan_type    slice_res slice_type  fold  scores/val_mean_dice_MYO  scores/val_mean_dice_LV  ...  scores/val_std_oa_exclude_bg_dice  scores/val_mean_hd95_MYO  scores/val_mean_hd95_LV  scores/val_mean_hd95_RV  scores/val_mean_hd95_LA  scores/val_mean_hd95_RA  scores/val_mean_oa_exclude_bg_hd95  scores/val_std_oa_exclude_bg_hd95  scores/val_mean_delta_vol_rel_LV  scores/val_std_delta_vol_rel_LV
# _id                                                                                                                                                  ...
# 0      0  $(1.5mm)^3$            p2CH            p4CH           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 1      1  $(1.5mm)^3$             2CH             4CH           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 2      2  $(1.5mm)^3$             2CH              SA           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 3      3  $(1.5mm)^3$             RND             RND           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 4      4  $(1.5mm)^3$             RND             RND           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 5      5  $(1.5mm)^3$             RND             RND           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 6      6  $(1.5mm)^3$             RND             RND           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 7      7  $(1.5mm)^3$             RND             RND           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 8      8  $(1.5mm)^3$             RND             RND           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 9      9  $(1.5mm)^3$              AX             COR           GT  $(1.5mm)^2$         GT     0                      81.7                     90.1  ...                                9.5                       7.5                      7.0                     17.7                     14.5                     22.8                                13.9                                7.9                               9.0                              8.4
# 10    10    $(6mm)^3$   best clinical   best clinical           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 11    11    $(6mm)^3$  best optimized  best optimized           GT  $(1.5mm)^2$         GT     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 12    12    $(6mm)^3$   best clinical   best clinical          SEG  $(1.5mm)^2$        SEG     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 13    13    $(6mm)^3$  best optimized  best optimized          SEG  $(1.5mm)^2$        SEG     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 14    14    $(6mm)^3$   best clinical   best clinical          SEG    $(6mm)^3$        SEG     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
# 15    15    $(6mm)^3$  best optimized  best optimized          SEG    $(6mm)^3$        SEG     0                      82.9                     91.8  ...                               10.0                       7.3                      5.9                     17.0                     15.2                     23.7                                13.8                                8.0                               3.8                              3.0
#
# [16 rows x 24 columns]

# %%
optimal_vals_maximize = filtered_frame[max_metrics_keys].idxmax()
optimal_vals_minimize = filtered_frame[min_metrics_keys].idxmin()

string_frame = filtered_frame.copy().astype(str)

# Fuse mean and std columns
for m in mean_keys:
    mean_col = string_frame[m].astype(str)
    std_col_key = m.replace("mean","std")
    if std_col_key in string_frame.columns:
        std_col = string_frame[std_col_key].astype(str)
        string_frame[m] = mean_col + r" \pm " + std_col
        string_frame.drop(std_col_key, axis=1, inplace=True)


# Add bold to optimal values
for col_name, idx in zip(optimal_vals_minimize.index, optimal_vals_minimize.values):
    row_idx = string_frame.index.get_loc(idx)
    col_idx = string_frame.columns.get_loc(col_name)
    string_frame.iloc[row_idx,col_idx] = r"\B " + string_frame.iloc[row_idx,col_idx]

for col_name, idx in zip(optimal_vals_maximize.index, optimal_vals_maximize.values):
    row_idx = string_frame.index.get_loc(idx)
    col_idx = string_frame.columns.get_loc(col_name)
    string_frame.iloc[row_idx,col_idx] = r"\B " + string_frame.iloc[row_idx,col_idx]

def join_cols(frame, first_col_key, second_col_key, join_str="+", drop_second=True):
    first_col = frame[first_col_key].astype(str)
    second_col = frame[second_col_key].astype(str)
    frame[first_col_key] = first_col + join_str + second_col
    if drop_second:
        frame.drop(second_col_key, axis=1, inplace=True)
    else:
        frame.drop(first_col_key, axis=1, inplace=True)
    return frame

# Join first and second view
string_frame = join_cols(string_frame, 'first_view', 'second_view', join_str=r"+")
string_frame = join_cols(string_frame, 'prescan_type', 'prescan_res', join_str=r" ", drop_second=False)
string_frame = join_cols(string_frame, 'slice_type', 'slice_res', join_str=r" ")


# Replace column names
string_frame.columns = [wanted_keys[c] for c in string_frame.columns]

string_frame.drop('_id', axis=1, inplace=True)
string_frame.drop('fold', axis=1, inplace=True)

string_frame.insert(3, ' ', len(string_frame)*["\hspace{1pt}"])
string_frame.insert(10, '  ', len(string_frame)*["\hspace{1pt}"])
string_frame.insert(17, '   ', len(string_frame)*["\hspace{1pt}"])

string_frame
# Out:
#     Precsan props.                  Slice view(s)     Slice props.                    MYO       LV       RV       LA       RA \multicolumn{1}{c}{ALL$\pm\sigma$ }                   MYO      LV       RV       LA       RA \multicolumn{1}{c}{ALL$\pm\sigma$  }               \multicolumn{1}{c}{ALL$\pm\sigma$   }
# _id
# 0      $(1.5mm)^3$                      p2CH+p4CH   GT $(1.5mm)^2$  \hspace{1pt}  \B 82.9  \B 91.8  \B 77.8     79.3     66.6                    \B 79.7 \pm 10.0  \hspace{1pt}  \B 7.3  \B 5.9  \B 17.0     15.2     23.7                      \B 13.8 \pm 8.0  \hspace{1pt}                        \B 3.8 \pm 3.0
# 1      $(1.5mm)^3$                        2CH+4CH   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 2      $(1.5mm)^3$                         2CH+SA   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 3      $(1.5mm)^3$                        RND+RND   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 4      $(1.5mm)^3$                        RND+RND   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 5      $(1.5mm)^3$                        RND+RND   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 6      $(1.5mm)^3$                        RND+RND   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 7      $(1.5mm)^3$                        RND+RND   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 8      $(1.5mm)^3$                        RND+RND   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 9      $(1.5mm)^3$                         AX+COR   GT $(1.5mm)^2$  \hspace{1pt}     81.7     90.1     77.4  \B 79.6  \B 68.9                        79.5 \pm 9.5  \hspace{1pt}     7.5     7.0     17.7  \B 14.5  \B 22.8                         13.9 \pm 7.9  \hspace{1pt}                           9.0 \pm 8.4
# 10       $(6mm)^3$    best clinical+best clinical   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 11       $(6mm)^3$  best optimized+best optimized   GT $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 12       $(6mm)^3$    best clinical+best clinical  SEG $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 13       $(6mm)^3$  best optimized+best optimized  SEG $(1.5mm)^2$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 14       $(6mm)^3$    best clinical+best clinical    SEG $(6mm)^3$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0
# 15       $(6mm)^3$  best optimized+best optimized    SEG $(6mm)^3$  \hspace{1pt}     82.9     91.8     77.8     79.3     66.6                       79.7 \pm 10.0  \hspace{1pt}     7.3     5.9     17.0     15.2     23.7                         13.8 \pm 8.0  \hspace{1pt}                           3.8 \pm 3.0

# %%
PM_COL_FORMAT = "S[table-figures-decimal=1,separate-uncertainty=true,table-format=3.1(3)]"
COL_FORMAT = \
    ("c" * 9) \
    + PM_COL_FORMAT \
    + ("c" * 6) \
    + PM_COL_FORMAT \
    + "c" \
    + PM_COL_FORMAT
# 19 cols

header = [r'\multicolumn{3}{c}{\textbf{Experiment I}}'] \
    + 2*[None] \
    + [r'\hspace{1pt}'] \
    + [r'\multicolumn{6}{c}{\textbf{Dice in \% $\uparrow$}}'] + 5*[None] \
    + [r'\hspace{1pt}'] \
    + [r'\multicolumn{6}{c}{\textbf{HD95 in mm $\downarrow$}}'] + 5*[None] \
    + [r'\hspace{1pt}'] \
    + [r'\textbf{$\Delta$vol in \%}']

latex_frame = pd.concat([pd.DataFrame(header, index=string_frame.columns).T, string_frame])

latex_frame.to_latex(
    buf="mmwhs_results.txt",
    escape=False,
    column_format=COL_FORMAT,
    index=False,
)
# Out:
# 19
